# %%
import matplotlib.pyplot as plt 
import pandas as pd
import mplfinance as mpf
# %matplotlib inline

# %%
data = pd.read_csv('Amazon.csv')
data
# Out:
#             Date         Open         High          Low        Close  \
# 0     1997-05-15     2.437500     2.500000     1.927083     1.958333
# 1     1997-05-16     1.968750     1.979167     1.708333     1.729167
# 2     1997-05-19     1.760417     1.770833     1.625000     1.708333
# 3     1997-05-20     1.729167     1.750000     1.635417     1.635417
# 4     1997-05-21     1.635417     1.645833     1.375000     1.427083
# ...          ...          ...          ...          ...          ...
# 6150  2021-10-21  3414.250000  3440.280029  3403.000000  3435.010010
# 6151  2021-10-22  3421.000000  3429.840088  3331.300049  3335.550049
# 6152  2021-10-25  3335.000000  3347.800049  3297.699951  3320.370117
# 6153  2021-10-26  3349.510010  3416.120117  3343.979980  3376.070068
# 6154  2021-10-27  3388.000000  3412.000000  3371.453369  3396.189941
#
#         Adj Close    Volume
# 0        1.958333  72156000
# 1        1.729167  14700000
# 2        1.708333   6106800
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6155 entries, 0 to 6154
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6155 non-null   object
#  1   Open       6155 non-null   float64
#  2   High       6155 non-null   float64
#  3   Low        6155 non-null   float64
#  4   Close      6155 non-null   float64
#  5   Adj Close  6155 non-null   float64
#  6   Volume     6155 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 336.7+ KB

# %%
data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
data.Date = pd.to_datetime(data.Date)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6155 entries, 0 to 6154
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6155 non-null   datetime64[ns]
#  1   Open       6155 non-null   float64
#  2   High       6155 non-null   float64
#  3   Low        6155 non-null   float64
#  4   Close      6155 non-null   float64
#  5   Adj Close  6155 non-null   float64
#  6   Volume     6155 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 336.7 KB

# %%
data = data.set_index('Date')

# %%
data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1997-05-15     2.437500     2.500000     1.927083     1.958333     1.958333
# 1997-05-16     1.968750     1.979167     1.708333     1.729167     1.729167
# 1997-05-19     1.760417     1.770833     1.625000     1.708333     1.708333
# 1997-05-20     1.729167     1.750000     1.635417     1.635417     1.635417
# 1997-05-21     1.635417     1.645833     1.375000     1.427083     1.427083
# ...                 ...          ...          ...          ...          ...
# 2021-10-21  3414.250000  3440.280029  3403.000000  3435.010010  3435.010010
# 2021-10-22  3421.000000  3429.840088  3331.300049  3335.550049  3335.550049
# 2021-10-25  3335.000000  3347.800049  3297.699951  3320.370117  3320.370117
# 2021-10-26  3349.510010  3416.120117  3343.979980  3376.070068  3376.070068
# 2021-10-27  3388.000000  3412.000000  3371.453369  3396.189941  3396.189941
#
#               Volume
# Date
# ...

# %%
mpf.plot(data)
# Out:
# D:\anaconda3\envs\{tunglam}\lib\site-packages\mplfinance\_arg_validators.py:45: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   category=UserWarning)

# %%
mpf.plot(data, type='line', volume=True)

# %%
mpf.plot(data['2021-02'], volume=True)
# Out:
# D:\anaconda3\envs\{tunglam}\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.

# %%
mpf.plot(data['2021-02'],type='candle' ,volume=True)
# Out:
# D:\anaconda3\envs\{tunglam}\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.

# %%
mpf.plot(data['2021-02':'2021-06'],type='candle', mav=(20) ,volume=True)

# %%
mpf.plot(data['2021-02':'2021-06'],type='candle', mav=(20) ,volume=True, tight_layout=True)

# %%
mpf.plot(
    data['2021-02':'2021-06'],
    figratio=(20,12),
    type='candle', 
    title='Amazon Stock Price in 2021',
    mav=(20) ,
    volume=True, 
    tight_layout=True
)

# %%
mpf.plot(
    data['2021-02':'2021-06'],
    # figratio=(30,10),
    figsize=(15, 5),
    title='Cổ phiếu Amazon năm 2021',
    type='candle', 
    mav=(20) ,
    ylabel='Giá cổ phiếu ($)',
    volume=True, 
    ylabel_lower = 'Số lượng cổ phiếu',
    tight_layout=True,
    style='yahoo'
)
